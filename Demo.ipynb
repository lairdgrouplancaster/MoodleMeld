# %% [markdown]
# ## Examples:
# ### Graphical interface (recommended):

# %%
from Moodlemeld import moodlemeld

moodlemeld(initials="MKR") # Set your intials here
# On a Mac you will get a warning: "The class 'NSOpenPanel' overrides the method identifier.  This method is implemented by class 'NSWindow'".
# This doesn't seem to be a problem.

# %% [markdown]
# ### Text interfaces:

# %%
# To meld:
from Meld import meld

meld("Sample data", True)

# %%
#  To unmeld:
from Unmeld import unmeld

unmeld("melded_PDF.pdf","MKR", True)

# %%
# To scale PDF to width (useful for testing/debugging):
from Meld import scale_pdf_to_width
from pathlib import Path

scale_pdf_to_width(Path("melded_PDF.pdf"), 595)
